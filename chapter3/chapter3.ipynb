# %%
with open('./neko.txt', mode='r', encoding='utf-8') as f:
    wagahai = f.read()

# sep = "。"
# wagahai_list = wagahai.split(sep)

# %%
from janome.tokenizer import Tokenizer

t = Tokenizer()

list(t.tokenize(wagahai))
# Out:
# ...
#  ...]
